# %%
#Pandas Library-import pandas as pd
import pandas as pd
# Pandas library it is used for data manipulation
# pandas it is a open source library
#pandas is fast and it has high performance and productivity for user.
#It is mainly popular for importing and analyzing data much easier
#Pandas is an open-source library that is made mainly for working with relational or labeled data both easily and intuitively.
#It provides various data structures and operation.

# %%
#hi i am trying things to be done

# %%
#Advantages 
#Fast and efficient for manipulating and analyzing data. 
#Data from different file objects can be loaded. 
#Easy handling of missing data (represented as NaN) in floating point as well as non-floating point data 
#Size mutability: columns can be inserted and deleted from DataFrame and higher dimensional objects 
#Data set merging and joining.


#Pandas is one of those packages and makes importing and analyzing data much easier.

# %%
#2) Mention the different types of Data Structures in Pandas?
# Their are 2 types of data structure
#1)series-It is one diamensional stucture in pandas
#2)DataFrame-It is two dimensional data structure in pandas
#The row labels of series are called the index. By using a 'series' method,
#we can easily convert the list, tuple, and dictionary into series. A Series cannot contain multiple columns.

# %%
#A DataFrame is a widely used data structure of pandas and 
#works with a two-dimensional array with labeled axes (rows and columns) DataFrame is defined as a standard way to store data
#and has two different indexes, i.e., row index and column index.

# %%
#What are the significant features of the pandas Library?
#Memory Efficient
#Data Alignment
#Reshaping
#Merge and join
#Time Series

# %%
#8) What is the name of Pandas library tools used to create a scatter plot matrix?
#scatter_matrix

# %%
#9)# Creating a dataframe by using list
#craete a dataframe from dict of ndarray

# %%
import pandas as pd
a=['python','pandas']

# %%
import pandas as pd
cr=pd.read_csv(r'F:\PGA22\Data Science\pandas_Dataset\creditrisk.csv')
cr.head(5)
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr.tail(5)
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 976             4009             1777.0       113.0             360.0
# 977             4158              709.0       115.0             360.0
# 978             3250             1993.0       126.0             360.0
# 979             5000             2393.0       158.0             360.0
# 980             9200                0.0        98.0             180.0
#
#      Credit_History Property_Area Loan_Status
# 976             1.0         Urban           Y
# ...

# %%
cr.shape
# Out:
# (981, 13)

# %%
cr.isnull().sum()
# Out:
# Loan_ID               0
# Gender               24
# Married               3
# Dependents           25
# Education             0
# Self_Employed        55
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
type(cr)
# Out:
# pandas.core.frame.DataFrame

# %%
cr.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
cr.ApplicantIncome.describe()
# Out:
# count      981.000000
# mean      5179.795107
# std       5695.104533
# min          0.000000
# 25%       2875.000000
# 50%       3800.000000
# 75%       5516.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(cr.ApplicantIncome)
# Out:
# (array([866.,  87.,  17.,   3.,   4.,   0.,   1.,   1.,   1.,   1.]),
#  array([    0.,  8100., 16200., 24300., 32400., 40500., 48600., 56700.,
#         64800., 72900., 81000.]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
sns.boxplot(cr.ApplicantIncome)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ApplicantIncome'>

# %%
cr.Gender.value_counts()
# Out:
# Male      775
# Female    182
# Name: Gender, dtype: int64

# %%
cr.describe(include ='all')### it showes descrbie numeric and categorical database)
# Out:
#          Loan_ID Gender Married  Dependents Education Self_Employed  \
# count        981    957     978  956.000000       981           926
# unique       981      2       2         NaN         2             2
# top     LP001107   Male     Yes         NaN  Graduate            No
# freq           1    775     631         NaN       763           807
# mean         NaN    NaN     NaN    0.881799       NaN           NaN
# std          NaN    NaN     NaN    1.255623       NaN           NaN
# min          NaN    NaN     NaN    0.000000       NaN           NaN
# 25%          NaN    NaN     NaN    0.000000       NaN           NaN
# 50%          NaN    NaN     NaN    0.000000       NaN           NaN
# 75%          NaN    NaN     NaN    2.000000       NaN           NaN
# max          NaN    NaN     NaN    4.000000       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        981.000000         981.000000  954.000000        961.000000
# ...

# %%
# How to handle null value in pandas

# %%
## so before the molding we make sure no nulls are present
#outherelise it showes error
# below are two ways of dealing with null values
# when you hane nulls we can do just remove the nulls
#replace the null swith some logical value




#what is null---a missing value is denoted by NaN . most developers would know as null val
#ues as missing or missing data in pandas.

# %%
cr1=cr.dropna()# here drop the all na values
cr1.shape
# Out:
# (769, 13)

# %%
cr1.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# 5      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 975    False   False    False       False      False          False
# 976    False   False    False       False      False          False
# 977    False   False    False       False      False          False
# 979    False   False    False       False      False          False
# 980    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1              False              False       False             False
# ...

# %%
## whenev nulls you will fills the based on your assumptions of the problem 
#statements their is no fixed rule that i have to fill mean or median or mode

# %%
cr.Credit_History.value_counts()## its showes the particular count of the columns
# Out:
# 1.0    754
# 0.0    148
# Name: Credit_History, dtype: int64

# %%
cr.isnull().sum()
# Out:
# Loan_ID               0
# Gender               24
# Married               3
# Dependents           25
# Education             0
# Self_Employed        55
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
cr.Loan_Amount_Term
# Out:
# 0      360.0
# 1      360.0
# 2      360.0
# 3      360.0
# 4      360.0
#        ...
# 976    360.0
# 977    360.0
# 978    360.0
# 979    360.0
# 980    180.0
# Name: Loan_Amount_Term, Length: 981, dtype: float64

# %%
cr.Loan_Amount_Term.mean()
# Out:
# 342.2018730489074

# %%
cr.Loan_Amount_Term.median()
# Out:
# 360.0

# %%
cr.Loan_Amount_Term.mode()
# Out:
# 0    360.0
# dtype: float64

# %%
cr.Gender.value_counts()
# Out:
# Male      775
# Female    182
# Name: Gender, dtype: int64

# %%
cr.LoanAmount
# Out:
# 0        NaN
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 976    113.0
# 977    115.0
# 978    126.0
# 979    158.0
# 980     98.0
# Name: LoanAmount, Length: 981, dtype: float64

# %%
cr.LoanAmount.mean()
# Out:
# 142.51153039832286

# %%
#cr.Gender=cr.Gender.fillna('Male')
#cr.LoanAmount=cr.LoanAmount.fillna(142.51153039832286)
cr.Gender=cr.Gender.fillna('male')
cr.Married=cr.Married.fillna('No')
cr.Dependents=cr.Dependents.fillna("No")
cr.Self_Employed=cr.Self_Employed.fillna("yes")
cr.LoanAmount=cr.LoanAmount.fillna(142.51153039832286)
cr.Loan_Amount_Term=cr.Loan_Amount_Term.fillna(342.2018730489074)
cr.Credit_History=cr.Credit_History.fillna(1)## here we put 1 beacuse it use in number of time

# %%
cr.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
## lets do the slicing and dicing of the dataframe
#Python slicing is about obtaining a sub-string from the given string by slicing it respectively from start to end.

# %%
#The slice() function returns a slice object that is used to slice any sequence

# %%
# Dataframe
# #A Data frame is a two-dimensional data structure
#i.e., data is aligned in a tabular fashion in rows and columns. 
#We can perform basic operations on rows/columns like selecting, deleting, adding, and renaming.

# %%
cr.iloc[[0,9,399,499,588],[0,1,2,3,5]]
# Out:
#       Loan_ID  Gender Married Dependents Self_Employed
# 0    LP001002    Male      No        0.0            No
# 9    LP001020    Male     Yes        1.0            No
# 399  LP002287  Female      No        0.0            No
# 499  LP002602    Male      No        0.0            No
# 588  LP002925    Male      No        0.0            No

# %%
cr2=cr[cr.ApplicantIncome>=3000]
cr2.head()
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No        0.0  Graduate            No
# 1  LP001003   Male     Yes        1.0  Graduate            No
# 2  LP001005   Male     Yes        0.0  Graduate           Yes
# 4  LP001008   Male      No        0.0  Graduate            No
# 5  LP001011   Male     Yes        2.0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0   142.51153             360.0
# 1             4583             1508.0   128.00000             360.0
# 2             3000                0.0    66.00000             360.0
# 4             6000                0.0   141.00000             360.0
# 5             5417             4196.0   267.00000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# ...

# %%
# Drop function is used for the drop the column
cr6=cr2.drop(['Loan_ID'],axis=1)
cr6.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
import pandas as pd
cr=pd.read_csv(r'F:\PGA22\Data Science\pandas_Dataset\creditrisk.csv')
cr.head(5)
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr.groupby(['Gender','Education','Self_Employed']).ApplicantIncome.median().round()
# Out:
# Gender  Education     Self_Employed
# Female  Graduate      No                3655.0
#                       Yes               5500.0
#         Not Graduate  No                2599.0
#                       Yes              12202.0
# Male    Graduate      No                3990.0
#                       Yes               5833.0
#         Not Graduate  No                3276.0
#                       Yes               4198.0
# Name: ApplicantIncome, dtype: float64

# %%
cr.groupby(["Education"]).ApplicantIncome.median().round()
# Out:
# Education
# Graduate        4000
# Not Graduate    3333
# Name: ApplicantIncome, dtype: int64

# %%
### replace function and this is extremly important it is used to, replce
##it is used to convert numeric to non numeric before any molding your entire data is in number

# %%
### you can mark any of them as azero
cr.Gender=cr.Gender.replace({'Male':0,"Female":0})

# %%
# One hot encoading- create dummy varaiables
#1indicate presence 0 indicate abscence

# %%
cr1=pd.get_dummies(cr)

# %%
cr1.head()
# Out:
#    Gender  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0     0.0         0.0             5849                0.0         NaN
# 1     0.0         1.0             4583             1508.0       128.0
# 2     0.0         0.0             3000                0.0        66.0
# 3     0.0         0.0             2583             2358.0       120.0
# 4     0.0         0.0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History  Loan_ID_LP001002  Loan_ID_LP001003  \
# 0             360.0             1.0                 1                 0
# 1             360.0             1.0                 0                 1
# 2             360.0             1.0                 0                 0
# 3             360.0             1.0                 0                 0
# 4             360.0             1.0                 0                 0
#
#    Loan_ID_LP001005  ...  Married_Yes  Education_Graduate  \
# ...

# %%
# Here one another way used convert categorical to neumerical value

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
pd.crosstab(cr.Education,cr.Loan_Status)
# Out:
# Loan_Status     N    Y
# Education
# Graduate      196  567
# Not Graduate   73  145

# %%
#2) Mention the different types of Data Structures in Pandas?
#Pandas provide two data structures, which are supported by the pandas library, Series, and DataFrames. 
#Both of these data structures are built on top of the NumPy.
#A Series is a one-dimensional data structure in pandas, whereas the DataFrame is the two-dimensional data structure in pandas.

# %%
# Create dataframe using list
import pandas as pd
a=['jb','sk','pk']
print(a)
b=pd.DataFrame(a)
print(b)
# Out:
# ['jb', 'sk', 'pk']
#     0
# 0  jb
# 1  sk
# 2  pk

# %%
#Example-2: Create a DataFrame from dict of ndarrays:
#info={"jagu":10,"atual":25}
#jb=pd.DataFrame(info)
#print(jb)

# %%
#A Categorical data is defined as a Pandas data type that corresponds to a categorical variable in statistics.
#A categorical variable is generally used to take a limited and usually fixed number of possible values.
#Examples: gender, country affiliation, blood type, social class, observation time, or rating via Likert scales.
#All values of categorical data are either in categories or np.nan.

# %%
#11) How will you create a series from dict in Pandas?
#A Series is defined as a one-dimensional array that is capable of storing various data types.
import pandas as pd
import numpy as np
info = {'x' : 0., 'y' : 1., 'z' : 2.}    
a = pd.Series(info)    
print (a)
# Out:
# x    0.0
# y    1.0
# z    2.0
# dtype: float64

# %%
#12) How can we create a copy of the series in Pandas?
# We can create the copy of series by using the following syntax:
#import pandas as pd
#pd.Series.copy
#Series.copy(deep=True)

# %%
# How to creat empty dataframe
# importing the pandas library    
import pandas as pd    
info = pd.DataFrame()    
print (info)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
cr=pd.read_csv(r'F:\PGA22\Data Science\pandas_Dataset\creditrisk.csv')
cr.head(5)
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            981 non-null    object
#  1   Gender             957 non-null    object
#  2   Married            978 non-null    object
#  3   Dependents         956 non-null    float64
#  4   Education          981 non-null    object
#  5   Self_Employed      926 non-null    object
#  6   ApplicantIncome    981 non-null    int64
#  7   CoapplicantIncome  981 non-null    float64
#  8   LoanAmount         954 non-null    float64
#  9   Loan_Amount_Term   961 non-null    float64
#  10  Credit_History     902 non-null    float64
#  11  Property_Area      981 non-null    object
#  12  Loan_Status        981 non-null    object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 99.8+ KB

# %%
pd.set_option('display.max_columns',85)

# %%
cr.tail(20)
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 961  LP002885    Male      No         0.0  Not Graduate            No
# 962  LP002890    Male     Yes         2.0  Not Graduate            No
# 963  LP002891    Male     Yes         0.0      Graduate           Yes
# 964  LP002899    Male     Yes         2.0      Graduate            No
# 965  LP002901    Male      No         0.0      Graduate            No
# 966  LP002907    Male     Yes         0.0      Graduate            No
# 967  LP002920    Male     Yes         0.0      Graduate            No
# 968  LP002921    Male     Yes         4.0  Not Graduate            No
# 969  LP002932    Male     Yes         4.0      Graduate            No
# 970  LP002935    Male     Yes         1.0      Graduate            No
# 971  LP002952    Male      No         0.0      Graduate            No
# 972  LP002954    Male     Yes         2.0  Not Graduate            No
# ...

# %%
## Example lets create one dataframe here
person={'first':['jagu','Aru','kanu'],'Last':['Bhapkar','Karmarkar','princes'],'Email':['JB@','RV@','SK@']}
pk=pd.DataFrame(person)
print(pk)
# Out:
#   first       Last Email
# 0  jagu    Bhapkar   JB@
# 1   Aru  Karmarkar   RV@
# 2  kanu    princes   SK@

# %%
person['Email']
# Out:
# ['JB@', 'RV@', 'SK@']

# %%
type(pk['Email'])
# Out:
# pandas.core.series.Series

# %%
pk.Email
# Out:
# 0    JB@
# 1    RV@
# 2    SK@
# Name: Email, dtype: object

# %%
pk[['first','Last']]
# Out:
#   first       Last
# 0  jagu    Bhapkar
# 1   Aru  Karmarkar
# 2  kanu    princes

# %%
pk.columns
# Out:
# Index(['first', 'Last', 'Email'], dtype='object')

# %%
pk.iloc[[0,1],2]
# Out:
# 0    JB@
# 1    RV@
# Name: Email, dtype: object

# %%
pk.iloc[1]
# Out:
# first          Aru
# Last     Karmarkar
# Email          RV@
# Name: 1, dtype: object

# %%
pk
# Out:
#   first       Last Email
# 0  jagu    Bhapkar   JB@
# 1   Aru  Karmarkar   RV@
# 2  kanu    princes   SK@

# %%
pk.loc[0]
# Out:
# first       jagu
# Last     Bhapkar
# Email        JB@
# Name: 0, dtype: object

# %%
pk.iloc[0]
# Out:
# first       jagu
# Last     Bhapkar
# Email        JB@
# Name: 0, dtype: object

# %%
pk.loc[[0,1],['Email','Last']]
# Out:
#   Email       Last
# 0   JB@    Bhapkar
# 1   RV@  Karmarkar

# %%
pk.shape
# Out:
# (3, 3)

# %%
pk['Email'].value_counts()
# Out:
# RV@    1
# SK@    1
# JB@    1
# Name: Email, dtype: int64

# %%
pk.columns
# Out:
# Index(['first', 'Last', 'Email'], dtype='object')

# %%
## Example lets create one dataframe here
person={'first':['jagu','Aru','kanu'],'Last':['Bhapkar','Karmarkar','princes'],'Email':['JB@','RV@','SK@']}
pk=pd.DataFrame(person)
print(pk)
# Out:
#   first       Last Email
# 0  jagu    Bhapkar   JB@
# 1   Aru  Karmarkar   RV@
# 2  kanu    princes   SK@

# %%
pk.reset_index(inplace=True)
pk
# Out:
#    index first       Last Email
# 0      0  jagu    Bhapkar   JB@
# 1      1   Aru  Karmarkar   RV@
# 2      2  kanu    princes   SK@

# %%
import pandas as pd
cr=pd.read_csv(r'F:\PGA22\Data Science\pandas_Dataset\creditrisk.csv',index_col='Loan_ID')
cr.head(5)
# Out:
#          Gender Married  Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No         0.0      Graduate            No
# LP001003   Male     Yes         1.0      Graduate            No
# LP001005   Male     Yes         0.0      Graduate           Yes
# LP001006   Male     Yes         0.0  Not Graduate            No
# LP001008   Male      No         0.0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# ...

# %%
schema_df
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002   Male      No         0.0      Graduate            No
# 1    LP001003   Male     Yes         1.0      Graduate            No
# 2    LP001005   Male     Yes         0.0      Graduate           Yes
# 3    LP001006   Male     Yes         0.0  Not Graduate            No
# 4    LP001008   Male      No         0.0      Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
## Example lets create one dataframe here
person={'first':['jagu','Aru','kanu'],'Last':['Bhapkar','Karmarkar','princes'],'Email':['JB@','RV@','SK@']}
pk=pd.DataFrame(person)
print(pk)
# Out:
#   first       Last Email
# 0  jagu    Bhapkar   JB@
# 1   Aru  Karmarkar   RV@
# 2  kanu    princes   SK@

# %%
pk['Last']=='Bhapkar'
# Out:
# 0     True
# 1    False
# 2    False
# Name: Last, dtype: bool

# %%
filter=(pk['Last']=='Bhapkar')
pk[filter]
# Out:
#   first     Last Email
# 0  jagu  Bhapkar   JB@

# %%
pk.loc[filter]
# Out:
#   first     Last Email
# 0  jagu  Bhapkar   JB@

# %%
pk.loc[filter,'Email']
# Out:
# 0    JB@
# Name: Email, dtype: object

# %%
import pandas as pd
cr=pd.read_csv(r'F:\PGA22\Data Science\pandas_Dataset\creditrisk.csv',index_col='Loan_ID')
cr.head(5)
# Out:
#          Gender Married  Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No         0.0      Graduate            No
# LP001003   Male     Yes         1.0      Graduate            No
# LP001005   Male     Yes         0.0      Graduate           Yes
# LP001006   Male     Yes         0.0  Not Graduate            No
# LP001008   Male      No         0.0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# ...

# %%
## Example lets create one dataframe here
person={'first':['jagu','Aru','kanu'],'Last':['Bhapkar','Karmarkar','princes'],'Email':['JB@','RV@','SK@']}
pk=pd.DataFrame(person)
print(pk)
# Out:
#   first       Last Email
# 0  jagu    Bhapkar   JB@
# 1   Aru  Karmarkar   RV@
# 2  kanu    princes   SK@

# %%
import pandas as pd
cr=pd.read_csv(r'F:\PGA22\Data Science\pandas_Dataset\creditrisk.csv',index_col='Loan_ID')
#cr.head(5)

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
cr.head()
# Out:
#          Gender Married  Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No         0.0      Graduate            No
# LP001003   Male     Yes         1.0      Graduate            No
# LP001005   Male     Yes         0.0      Graduate           Yes
# LP001006   Male     Yes         0.0  Not Graduate            No
# LP001008   Male      No         0.0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# ...

# %%
ApplicantIncome=(cr['LoanAmount']>6000)

# %%
cr.loc[ApplicantIncome]
# Out:
# Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
## Example lets create one dataframe here
person={'first':['jagu','Aru','kanu'],'Last':['Bhapkar','Karmarkar','princes'],'Email':['JB@','RV@','SK@']}
pk=pd.DataFrame(person)
print(pk)
# Out:
#   first       Last Email
# 0  jagu    Bhapkar   JB@
# 1   Aru  Karmarkar   RV@
# 2  kanu    princes   SK@

# %%
pk.columns
# Out:
# Index(['first', 'Last', 'Email'], dtype='object')

# %%
pk.columns=['first_name','Last_name','Email_id']

# %%
pk.columns
# Out:
# Index(['first_name', 'Last_name', 'Email_id'], dtype='object')

# %%
pk.columns=[x.upper() for x in pk.columns]
pk
# Out:
#   FIRST_NAME  LAST_NAME EMAIL_ID
# 0       jagu    Bhapkar      JB@
# 1        Aru  Karmarkar      RV@
# 2       kanu    princes      SK@

# %%
#pk.columns=pk.columns.str.replace('  ','  ','  ')
pk.columns
# Out:
# Float64Index([nan, nan, nan], dtype='float64')

# %%
## Example lets create one dataframe here
person={'first':['jagu','Aru','kanu'],'Last':['Bhapkar','Karmarkar','princes'],'Email':['JB@','RV@','SK@']}
pk=pd.DataFrame(person)
print(pk)
# Out:
#   first       Last Email
# 0  jagu    Bhapkar   JB@
# 1   Aru  Karmarkar   RV@
# 2  kanu    princes   SK@

# %%
pk.rename(columns={'first':"First_name","Last":"Last_name","Email":"Email_id"},inplace=True)
pk
# Out:
#   First_name  Last_name Email_id
# 0       jagu    Bhapkar      JB@
# 1        Aru  Karmarkar      RV@
# 2       kanu    princes      SK@

# %%
pk.loc[2]=['jon','raje','tk@']
pk
# Out:
#   First_name  Last_name Email_id
# 0       jagu    Bhapkar      JB@
# 1        Aru  Karmarkar      RV@
# 2        jon       raje      tk@

# %%
filt=(pk['Email_id']=="dd")
pk[filt]['Last_name']
# Out:
# Series([], Name: Last_name, dtype: object)

# %%
pk['Email_id'].str.lower()
# Out:
# 0    jb@
# 1    rv@
# 2    tk@
# Name: Email_id, dtype: object

# %%
pk['Email_id'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# Name: Email_id, dtype: int64

# %%
def upper_email (Email_id):
    return Email_id.upper()

# %%
pk.apply(len)
# Out:
# First_name    3
# Last_name     3
# Email_id      3
# dtype: int64

# %%
len(pk['Email_id'])
# Out:
# 3

# %%
pk.apply(pd.Series.min)
# Out:
# First_name        Aru
# Last_name     Bhapkar
# Email_id          JB@
# dtype: object

# %%
pk.apply(lambda x:x.min())
# Out:
# First_name        Aru
# Last_name     Bhapkar
# Email_id          JB@
# dtype: object

# %%
pk.applymap(len)
# Out:
#    First_name  Last_name  Email_id
# 0           4          7         3
# 1           3          9         3
# 2           3          4         3

# %%
pk.applymap(str.lower)
# Out:
#   First_name  Last_name Email_id
# 0       jagu    bhapkar      jb@
# 1        aru  karmarkar      rv@
# 2        jon       raje      tk@

# %%
## Example lets create one dataframe here
person={'first':['jagu','Aru','kanu'],'Last':['Bhapkar','Karmarkar','princes'],'Email':['JB@','RV@','SK@']}
pk=pd.DataFrame(person)
print(pk)
# Out:
#   first       Last Email
# 0  jagu    Bhapkar   JB@
# 1   Aru  Karmarkar   RV@
# 2  kanu    princes   SK@

# %%
pk['first']+'  '+pk['Last']
# Out:
# 0     jagu  Bhapkar
# 1    Aru  Karmarkar
# 2     kanu  princes
# dtype: object

# %%
pk['Full_name']=pk['first']+'  '+pk['Last']
pk
# Out:
#   first       Last Email       Full_name
# 0  jagu    Bhapkar   JB@   jagu  Bhapkar
# 1   Aru  Karmarkar   RV@  Aru  Karmarkar
# 2  kanu    princes   SK@   kanu  princes

# %%
pk.drop(columns=['Email'])
# Out:
#   first       Last       Full_name
# 0  jagu    Bhapkar   jagu  Bhapkar
# 1   Aru  Karmarkar  Aru  Karmarkar
# 2  kanu    princes   kanu  princes

# %%
pk['Full_name'].str.split(' ',expand=True)
# Out:
#       0 1          2
# 0  jagu      Bhapkar
# 1   Aru    Karmarkar
# 2  kanu      princes

# %%
## Example lets create one dataframe here
person={'first':['jagu','Aru','kanu'],'Last':['Bhapkar','Karmarkar','princes'],'Email':['JB@','RV@','SK@']}
pk2=pd.DataFrame(person)
print(pk2)
# Out:
#   first       Last Email
# 0  jagu    Bhapkar   JB@
# 1   Aru  Karmarkar   RV@
# 2  kanu    princes   SK@

# %%
pk.append(pk2,ignore_index=True,sort=False)
# Out:
#   first       Last Email       Full_name
# 0  jagu    Bhapkar   JB@   jagu  Bhapkar
# 1   Aru  Karmarkar   RV@  Aru  Karmarkar
# 2  kanu    princes   SK@   kanu  princes
# 3  jagu    Bhapkar   JB@             NaN
# 4   Aru  Karmarkar   RV@             NaN
# 5  kanu    princes   SK@             NaN

# %%
pk.drop(2)
# Out:
#   first       Last Email       Full_name
# 0  jagu    Bhapkar   JB@   jagu  Bhapkar
# 1   Aru  Karmarkar   RV@  Aru  Karmarkar

# %%
## Example lets create one dataframe here
person={'first':['jagu','Aru','kanu'],'Last':['Bhapkar','Karmarkar','princes'],'Email':['JB@','RV@','SK@']}
pk2=pd.DataFrame(person)
print(pk2)
# Out:
#   first       Last Email
# 0  jagu    Bhapkar   JB@
# 1   Aru  Karmarkar   RV@
# 2  kanu    princes   SK@

# %%
pk2.sort_values(by='Last',ascending=False)
# Out:
#   first       Last Email
# 2  kanu    princes   SK@
# 1   Aru  Karmarkar   RV@
# 0  jagu    Bhapkar   JB@

# %%
import pandas as pd
cr=pd.read_csv(r'F:\PGA22\Data Science\pandas_Dataset\creditrisk.csv')
cr.head(5)
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr.isnull().sum()
# Out:
# Loan_ID               0
# Gender               24
# Married               3
# Dependents           25
# Education             0
# Self_Employed        55
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
cr.isna()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 976    False   False    False       False      False          False
# 977    False   False    False       False      False          False
# 978    False   False    False       False      False          False
# 979    False   False    False       False      False          False
# 980    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
cr.fillna('')
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No        0.0      Graduate            No
# 1    LP001003   Male     Yes        1.0      Graduate            No
# 2    LP001005   Male     Yes        0.0      Graduate           Yes
# 3    LP001006   Male     Yes        0.0  Not Graduate            No
# 4    LP001008   Male      No        0.0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 976  LP002971   Male     Yes        4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes        0.0      Graduate            No
# 978  LP002980   Male      No        0.0      Graduate            No
# 979  LP002986   Male     Yes        0.0      Graduate            No
# 980  LP002989   Male      No        0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0               5849                0.0                       360.0
# ...

# %%
cr.fillna('missing')
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No        0.0      Graduate            No
# 1    LP001003   Male     Yes        1.0      Graduate            No
# 2    LP001005   Male     Yes        0.0      Graduate           Yes
# 3    LP001006   Male     Yes        0.0  Not Graduate            No
# 4    LP001008   Male      No        0.0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 976  LP002971   Male     Yes        4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes        0.0      Graduate            No
# 978  LP002980   Male      No        0.0      Graduate            No
# 979  LP002986   Male     Yes        0.0      Graduate            No
# 980  LP002989   Male      No        0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0               5849                0.0    missing            360.0
# ...

# %%
cr.fillna(0)
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002   Male      No         0.0      Graduate            No
# 1    LP001003   Male     Yes         1.0      Graduate            No
# 2    LP001005   Male     Yes         0.0      Graduate           Yes
# 3    LP001006   Male     Yes         0.0  Not Graduate            No
# 4    LP001008   Male      No         0.0      Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
cr.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents           float64
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
cr['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-0a93989af28f> in <module>
# ----> 1 cr['age'].mean()
#
# ...
